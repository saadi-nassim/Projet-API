# %% [markdown]
# <h1>Projet Api  </h1>
# <h2>Réalisé par : </h2>
# <h2>Sid-Ali DJABELLA </h2>
#                  <h2>  Nassim SAADI </h2>
# <h2>Ilhem ATROUN </h2>

# %% [markdown]
# <h4> 1- Nous avons une API  avec beaucoup de données récupérer sur github api </h4>

# %%
url='https://www.cheapshark.com/api/1.0/deals'
print(url)
# Out:
# https://www.cheapshark.com/api/1.0/deals

# %%
import requests
data = requests.get(url)
data                            # 200==>la requette a marchée/404 na pas marché
# Out:
# <Response [200]>

# %%
data.headers
# Out:
# {'Date': 'Tue, 05 Jan 2021 20:50:26 GMT', 'Content-Type': 'application/json', 'Content-Length': '8068', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d5bcf4630e4f269488836f4dd77426ac21609879826; expires=Thu, 04-Feb-21 20:50:26 GMT; path=/; domain=.cheapshark.com; HttpOnly; SameSite=Lax; Secure', 'CF-Ray': '60d012523d14cd9f-CDG', 'Accept-Ranges': 'bytes', 'Access-Control-Allow-Origin': '*', 'Age': '254', 'Cache-Control': 'max-age=300, s-maxage=600, stale-while-revalidate=30, stale-if-error=60, public', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'CF-Cache-Status': 'HIT', 'cf-request-id': '0775e9c7680000cd9f329ab000000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'PHP-Cache': 'MISS', 'X-Powered-By': 'The love of games, an addiction to deals, and a bit of code! :), PleskLin', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report?s=eFa7QdbCy0OSygJwZeJCBu5y%2FrR4x%2FK9E9uIMPwAQMhYb2YqQ
# ...

# %% [markdown]
# <h4> 2- la fonction ci-dessous nous à permet d afficher le dictionnaire de données de ces API  (Liste des attributs possible)</h4>

# %%
import json 
data = json.loads(data.content)
data
# Out:
# [{'internalName': 'JURASSICWORLDEVOLUTION',
#   'title': 'Jurassic World Evolution',
#   'metacriticLink': '/game/pc/jurassic-world-evolution',
#   'dealID': '84s2NOrWv2FovsLkjXnAQJagnAEoeg%2BWH4JLW108%2FYg%3D',
#   'storeID': '25',
#   'gameID': '184656',
#   'salePrice': '0.00',
#   'normalPrice': '44.99',
#   'isOnSale': '1',
#   'savings': '100.000000',
#   'metacriticScore': '69',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '83',
#   'steamRatingCount': '33138',
#   'steamAppID': '648350',
#   'releaseDate': 1528675200,
#   'lastChange': 1609432449,
#   'dealRating': '10.0',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/648350/capsule_sm_120.jpg?t=1595319162'},
#  {'internalName': 'PAYDAY2LEGACYCOLLECTION',
#   'title': 'PAYDAY 2 - Legacy Collection',
#   'metacriticLink': None,
#   'dealID': 'AUpvPEfVwFrbLLRTt8SrFnHja7FGZ5z9u6j9Wjb9NF4%3D',
#   'storeID': '3',
#   'gameID': '207314',
#   'salePrice': '7.44',
#   'normalPrice': '78.34',
# ...

# %% [markdown]
# <h4> 3- Construire un Schéma de donnée pouvant stocker de manière structuré les données des APIs, affichage d un dataset</h4>

# %%
from pandas.io.json import json_normalize
dataSet = json_normalize (data)
dataSet                              #json normalize va nous afficher les donées sous forme d'un tableau (DataFrame)
# Out:
# <ipython-input-19-34854abd5f0d>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataSet = json_normalize (data)
#                                   internalName  \
# 0                       JURASSICWORLDEVOLUTION
# 1                      PAYDAY2LEGACYCOLLECTION
# 2                           HITMAN2GOLDEDITION
# 3    NARUTOTOBORUTOSHINOBISTRIKERDELUXEEDITION
# 4   NINOKUNIIIREVENANTKINGDOMTHEPRINCESEDITION
# 5                    PROJECTCARS2DELUXEEDITION
# 6            DRAGONBALLFIGHTERZFIGHTERZEDITION
# 7            DRAGONBALLFIGHTERZULTIMATEEDITION
# 8                                  MASSEFFECT2
# 9                                  MASSEFFECT2
# 10                      BROTHERSATALEOFTWOSONS
# 11                                 MASSEFFECT2
# 12                                 MASSEFFECT2
# 13                        STEALTHBASTARDDELUXE
# 14        AGEOFWONDERSPLANETFALLPREMIUMEDITION
# ...

# %% [markdown]
# <h4> 4- connection sur la base de données SQL server</h4>

# %%
import pyodbc 
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-B3P8MT0;'
                      'Database=Game;'
                      'Trusted_Connection=yes;')

# %% [markdown]
# <h4>5- Création de la base de donnée avec la structure définit et remplissage de la table sur sql </h4>

# %%
cursor = conn.cursor()
for i in range (len(data)):
    dataseta=[tuple(data[i].values())]
    cursor.executemany("INSERT INTO jeux (internalName, title,metacriticLink,dealID,storeID,gameID,salePrice ,normalPrice,isOnSale,savings,metacriticScore,steamRatingText,steamRatingPercent,steamRatingCount,steamAppID,releaseDate,lastChange,dealRating,thumb) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)", dataseta)
    conn.commit()

# %%
<>
